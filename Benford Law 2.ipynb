# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import benford as bf

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.6

# %%
wsa = pd.read_csv("teddylaw.csv")
wsa
# Out:
#      Accounting Numbers
# 0                   892
# 1                   892
# 2                171266
# 3                 17025
# 4                 20416
# ..                  ...
# 112              279967
# 113              279967
# 114              275730
# 115              275730
# 116                4237
#
# [117 rows x 1 columns]

# %%
listWSA = []
for i in wsa['Accounting Numbers']:
    listWSA.append(i)

# %%
oneDigit = bf.first_digits(listWSA, digs=1, decimals=8)
# Out:
# Initialized sequence with 117 registries.
# First_1_Dig
# 1    0.162393
# 2    0.324786
# 3    0.085470
# 4    0.111111
# 5    0.136752
# 6    0.085470
# 7    0.025641
# 8    0.025641
# 9    0.042735
# Name: Found, dtype: float64
#
# Test performed on 117 registries.
# Discarded 0 records < 1 after preparation.

# %%
ks = bf.first_digits(listWSA, digs=1, decimals=8, confidence=95)
# Out:
# Initialized sequence with 117 registries.
# First_1_Dig
# 1    0.162393
# 2    0.324786
# 3    0.085470
# 4    0.111111
# 5    0.136752
# 6    0.085470
# 7    0.025641
# 8    0.025641
# 9    0.042735
# Name: Found, dtype: float64
#
# Test performed on 117 registries.
# Discarded 0 records < 1 after preparation.
#
# The entries with the significant positive deviations are:
#
#              Expected     Found   Z_score
# First_1_Dig
# 2            0.176091  0.324786  4.101253
# 5            0.079181  0.136752  2.135013
